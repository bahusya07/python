# %% [markdown]
# #markdown

# %% [markdown]
# #markdown
# ##markdown
# ###markdown
# ####markdown

# %% [markdown]
# # insert site address
# [site](https://sites.google.com/view/crt-gitam-batch-2/home)

# %% [markdown]
# # insert image address
# ![site](https://images.pexels.com/photos/736230/pexels-photo-736230.jpeg?auto=compress&cs=tinysrgb&dpr=1&w=500)

# %% [markdown]
# # pythons basics
# python is a beginners language
#
# python is easy to learn

# %% [markdown]
# # creating ordered list
# 1.hi
#
# 2.hello
#
# 3.welcome

# %% [markdown]
# # creating unordered list
# - hi
# - bye

# %% [markdown]
# ## bold and italic text
# **bahusya**
#
# *bahusya*

# %%
#basic hello
print("hello world!!")
# Out:
# hello world!!

# %%
#variable creation
x=10
y=20
x+y
# Out:
# 30

# %% [markdown]
# # rules for variable
# - name should begin with a character
# - no special character allowed except _

# %%
name = "bahusya"
age = 20
print("my name is:",name,"\n my age is:",age)
# Out:
# my name is: bahusya
#  my age is: 20

# %%
name = input("enter name")
age = int(input("enter age"))
print("my name is:",name,"\n my age is:",age)
# Out:
# enter name bahusya
# enter age 20
# my name is:  bahusya
#  my age is: 20

# %%
x = int(input("enter a number"))
y = int(input("enter a number"))
print("add is:",x+y,"\nsub is:",x-y,"\n mul is:",x*y,"\n div is:",x/y,"\n mod is:",x%y)
# Out:
# enter a number10
# enter a number5
# add is: 15
# sub is: 5
#  mul is: 50
#  div is: 2.0
#  mod is: 0

# %% [markdown]
# # fundamental data types
# - int
# - float
# - complex
# - boolean
# - string

# %%
x = 10
y = 12.86
z = 4+2j
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
a = complex(2,4)
print(a)
# Out:
# (2+4j)

# %%
c1 = 2+4j
c2 = 3+5j
print(c1+c2)
print(c1-c2)
print(c1*c2)
# Out:
# (5+9j)
# (-1-1j)
# (-14+22j)

# %%
x = 5
y = 9
print(x<y)
print(x>y)
# Out:
# True
# False

# %%
# string
s1="abc"
s2="fgh"
print(type(s1))
print(type(s2))
# Out:
# <class 'str'>
# <class 'str'>

# %%
s1="abc"
s2=10
print(type(s1))
print(type(s2))
# Out:
# <class 'str'>
# <class 'int'>

# %%
i=100
print(type(i))
s1=str(i)
print(type(s1))
f1=float(i)
print(type(f1))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
# length
a =1234
print(len(str(a)))
# Out:
# 4

# %%
a = 123
print(len(str(a)))
# Out:
# 3

# %%
n1 = 50
a=b=c=10
a1,b1,c1 = 123,234,567
print(n1)
print(a,b,c)
print(a1,b1,c1)
# Out:
# 50
# 10 10 10
# 123 234 567

# %% [markdown]
# # precedence of the arth operators
# - parenthesis
# - power
# - multiplication
# - addition

# %%
x = 1+2**3/4+5
print(x)
# Out:
# 8.0

# %%
x= 1+2**3/4*5
print(x)
# Out:
# 11.0

# %% [markdown]
# # operators
# ## arithmetic operators
# - +
# - -
# -*
# -/
# -%
# -**
# - //

# %%
x=11
y=5
print(x+y)
print(x-y)
print(x*y)
print(x/y)
print(x%y)
print(x**y)
print(x//y)
# Out:
# 16
# 6
# 55
# 2.2
# 1
# 161051
# 2

# %% [markdown]
# # relational operators
# - == , !=, <= , >=, <, >

# %%
x =5 
a= x>10
print(a) 
b= x<10
print(b)
# Out:
# False
# True

# %% [markdown]
# # logical operators
# - and
# - or
# - not

# %%
i = 100
a1 = (i>15) and (i>50)
a2 = (i>500) and (i>600)
print(a1)
print(a2)
print(not i)
# Out:
# True
# False
# False

# %% [markdown]
# # membership operator
# - in
# - not in

# %%
str1= "abc"
print('a' in str1)
print('z' in str1)
# Out:
# True
# False

# %% [markdown]
# # control flow statements
# - conditional statements
# - looping statements
# --if-else statement
#
#   --syntax
#   ##### if condition:
#   > statements<br>
#   ##### else:
#   > statements

# %%
 # check given number is even or odd
 n = int(input("enter a number"))
 if n%2==0:
  print("even")
 else:
   print("odd")
# Out:
# enter a number10
# even

# %%
# check given number is perfectly mul;tiple of 3 and 5

n = int(input("enter a number"))
if n%3==0 and n%5==0:
  print("multilple")
else:
    print("not amultiple")
# Out:
# enter a number15
# multilple

# %%
#check given number is positive,negative or zero
n= int(input("enter a number"))
if n>0:
   print("positive")
elif n<0:
   print
