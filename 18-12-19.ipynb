# %%
#program to find the minimum no
#include<stdio.h>
#include<limits.h>
void main()
{
int a;
a=INT_MIN;
printf("%d",a);
}
# Out:
#   File "<ipython-input-1-354669010831>", line 1
#     void main()
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# # aschii values

# %%
#program to print achii values 
#include<stdio.h>
#include<limits.h>
void main()
{
int i=65;
for(i=65;i<=200;i++)
printf("%c=%d",i,i);
}

# %%
#include<stdio.h>
#include<limits.h>
void main()
{
int i=65;
for(i=65;i<=122;i++)
printf("%c=%d",i,i);
}

# %%
#include <stdio.h>
#include<limits.h>
void main()
{
printf("%d",'+');
}

# %% [markdown]
# # program to check \b \r \v \\ \a

# %%
#include <stdio.h>
#include<limits.h>
void main()
{
printf("abcd\b\bxyz");
}

# %%
#include <stdio.h>
#include<limits.h>
void main()
{
printf("abcd\fxyz");
}

# %%
#include <stdio.h>
#include<limits.h>
void main()
{
printf("abcd\axyz");
}

# %%
#include <stdio.h>
#include<limits.h>
void main()
{
int i=29;
printf("%o",i);
}

# %%
#include <stdio.h>
#include<limits.h>
void main()
{
int i=035;
printf("%d",i);
}

# %%
#include <stdio.h>
#include<limits.h>
void main()
{
int i=0x35;
printf("%d",i);
}

# %% [markdown]
# # operators

# %%
#include <stdio.h>
#include<limits.h>
void main()
{
printf("%d",'b'+'a');
}

# %%
#include <stdio.h>
#include<limits.h>
void main()
{
printf("%d",15%4);
}

# %%
#include <stdio.h>
#include<limits.h>
void main()
{
    float a;
    a=fmod(20.5,3.2);
printf("%f",a);
}

# %%
#include <stdio.h>
#include<limits.h>
void main()
{
    int b,a=5;
    b=++a;
printf("%d %d",a,b);
}

# %%
#include <stdio.h>
#include<limits.h>
void main()
{
    int b,a=5;
    b=++a;
printf("%d %d",a,b);
}

# %%
#include <stdio.h>
#include<limits.h>
void main()
{
    int b,a=5;
printf("%d %d",a++);
printf("%d",a);
}

# %%
#include <stdio.h>
#include<limits.h>
void main()
{
    int b,a=5;
printf("%d %d",a);
printf("%d",a);
}

# %%
#include <stdio.h>
void main()
{
    int a=5,b=9,c;
    c=b&&++a;
    printf("\n%d",a);
}

# %%
#include <stdio.h>
void main()
{
    int a=5,b=4,c;
    c=b||++a;
    printf("\n%d",a);
}

# %%
#include <stdio.h>
void main()
{
    int a=5,b=7,c,d=0;
    c=b||a&&d;
    printf("\n%d",c);
}

# %%
#include <stdio.h>
void main()
{
    int a=5,b=6,c;
    c=a<<6;
    printf("\n%d",c);
}

# %%
#include <stdio.h>
void main()
{
    int a=5,b=6,c;
    c=a&b;
    printf("\n%d",c);
}

# %%
#include <stdio.h>
void main()
{
    int a=5,b=6,c;
    c=a|b;
    printf("\n%d",c);
}

# %%
#include <stdio.h>
void main()
{
    int a=5,b=6,c;
    c=a^b;
    printf("\n%d",c);
}

# %%
#include <stdio.h>
void main()
{
    int a=5,b=6,c;
    c=a>>2;
    printf("\n%d",c);
}

# %%
#include <stdio.h>
void main()
{
    int a=5,b=6,c;
    c=~5;
    printf("\n%d",c);
}

# %%
#include <stdio.h>
void main()
{
    int a=-56,c;
    c=~a;
    printf("\n%d",c);
}

# %%
#include <stdio.h>
void main()
{
    int a=5,b=2;
    if(a==b)
    printf("yes");
    else
    printf("no");
    printf("\n%d",a);
}

# %%
#include <stdio.h>
void main()
{
    int a=5,b=2;
    if(a!=b)
    printf("yes");
    else
    printf("no");
    printf("\n%d",a);
}

# %%
#include <stdio.h>
void main()
{
    int a=5;
    a*=6;
    printf("\n%d",a);
}

# %%
#include <stdio.h>
void main()
{
    int a=5,b;
    b=sizeof(a++);
    printf("\n%d %d",a,b);
}

# %%
#include <stdio.h>
void main()
{
    int a=5,b;
    b=sizeof(++a);
    printf("\n%d %d",a,b);
}

# %%
#include <stdio.h>
void main()
{
    int a=5,b=6,c;
    c=a<b?a:b;
    printf("\n%d",c);
}

# %%
#include <stdio.h>
void main()
{
    int a=5,b=6,c;
    c=a>b?a:b;
    printf("\n%d",c);
}

# %%
#include <stdio.h>
void main()
{
    int a=6,b=5,c;
    c=a?0:1;
    printf("\n%d",c);
}

# %%
#include <stdio.h>
void main()
{
    int a=0,b=5,c;
    c=a?0:b;
    printf("\n%d",c);
}
